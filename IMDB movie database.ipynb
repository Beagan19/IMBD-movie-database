# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from urllib.parse import quote_plus as urlquote
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Datasets

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1962
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1800
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2601

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Basics Dataset

# %%
basics = basics.replace({'\\N':np.nan})

# %%
basics = basics.dropna(subset=['runtimeMinutes','genres','startYear'])

# %%
basics = basics.loc[basics['titleType'] == 'movie']

# %%
basics.head()
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                        Miss Jerry       0      1894     NaN             45
# 144   The Corbett-Fitzsimmons Fight       0      1897     NaN            100
# 570     The Story of the Kelly Gang       0      1906     NaN             70
# 587               L'enfant prodigue       0      1907     NaN             90
# 672  The Fairylogue and Radio-Plays       0      1908     NaN            120
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 570  Action,Adventure,Biography
# 587                       Drama
# 672           Adventure,Fantasy

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %% [markdown]
# ## Akas Dataset

# %%
akas = akas.replace({'\\N':np.nan})

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 8          True
# 570        True
# 587        True
# 672        True
# 930        True
#            ...
# 9714085    True
# 9714094    True
# 9714133    True
# 9714178    True
# 9714262    True
# Name: tconst, Length: 283279, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 930      tt0000941     movie                  Locura de amor
# ...            ...       ...                             ...
# 9714085  tt9916170     movie                   The Rehearsal
# 9714094  tt9916190     movie                       Safeguard
# 9714133  tt9916270     movie        Il talento del calabrone
# 9714178  tt9916362     movie                           Coven
# 9714262  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult startYear endYear  \
# 8                            Miss Jerry       0      1894     NaN
# 570         The Story of the Kelly Gang       0      1906     NaN
# 587                   L'enfant prodigue       0      1907     NaN
# 672      The Fairylogue and Radio-Plays       0      1908     NaN
# 930                      Locura de amor       0      1909     NaN
# ...                                 ...     ...       ...     ...
# 9714085                        O Ensaio       0      2019     NaN
# 9714094                       Safeguard       0      2020     NaN
# 9714133        Il talento del calabrone       0      2020     NaN
# 9714178                        Akelarre       0      2020     NaN
# 9714262             Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 672                120           Adventure,Fantasy
# 930                 45                       Drama
# ...                ...                         ...
# 9714085             51                       Drama
# 9714094             95   Action,Adventure,Thriller
# 9714133             84                    Thriller
# 9714178             92               Drama,History
# 9714262            123                       Drama
#
# [282530 rows x 9 columns]

# %% [markdown]
# ## Ratings Dataset

# %%
ratings = ratings.replace({'\\N':np.nan})

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(ratings['tconst'])
keepers
# Out:
# 8          True
# 570        True
# 587        True
# 672        True
# 930        True
#            ...
# 9714085    True
# 9714094    True
# 9714133    True
# 9714178    True
# 9714262    True
# Name: tconst, Length: 282530, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 930      tt0000941     movie                  Locura de amor
# ...            ...       ...                             ...
# 9714085  tt9916170     movie                   The Rehearsal
# 9714094  tt9916190     movie                       Safeguard
# 9714133  tt9916270     movie        Il talento del calabrone
# 9714178  tt9916362     movie                           Coven
# 9714262  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult startYear endYear  \
# 8                            Miss Jerry       0      1894     NaN
# 570         The Story of the Kelly Gang       0      1906     NaN
# 587                   L'enfant prodigue       0      1907     NaN
# 672      The Fairylogue and Radio-Plays       0      1908     NaN
# 930                      Locura de amor       0      1909     NaN
# ...                                 ...     ...       ...     ...
# 9714085                        O Ensaio       0      2019     NaN
# 9714094                       Safeguard       0      2020     NaN
# 9714133        Il talento del calabrone       0      2020     NaN
# 9714178                        Akelarre       0      2020     NaN
# 9714262             Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 672                120           Adventure,Fantasy
# 930                 45                       Drama
# ...                ...                         ...
# 9714085             51                       Drama
# 9714094             95   Action,Adventure,Thriller
# 9714133             84                    Thriller
# 9714178             92               Drama,History
# 9714262            123                       Drama
#
# [213785 rows x 9 columns]
